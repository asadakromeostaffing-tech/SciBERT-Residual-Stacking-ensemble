# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train.csv
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0192/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0192/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0956/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0956/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0266/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0266/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0435/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0435/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1054/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1054/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0664/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0664/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0599/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0599/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1004/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1004/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0658/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0658/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0686/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0686/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0491/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0491/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0026/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0026/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0722/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0722/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0951/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0951/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0743/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0743/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0959/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0959/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0177/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0177/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0799/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0799/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0572/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0572/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0669/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0669/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0417/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0417/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0438/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0438/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0191/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0191/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0993/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0993/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0494/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0494/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0745/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0745/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0075/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0075/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0728/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0728/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0554/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0554/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0173/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0173/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0478/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0478/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0801/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0801/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0695/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0695/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0738/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0738/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0634/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0634/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0063/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0063/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1020/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1020/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0603/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0603/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0825/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0825/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0532/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0532/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0559/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0559/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0506/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0506/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0251/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0251/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0094/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0094/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0884/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0884/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0308/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0308/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0955/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0955/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1045/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1045/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0071/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0071/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0842/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0842/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0073/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0073/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1026/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1026/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0246/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0246/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0090/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0090/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0301/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0301/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0938/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0938/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0253/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0253/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0085/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0085/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0566/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0566/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0606/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0606/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0872/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0872/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0306/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0306/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0220/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0220/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0252/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0252/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0247/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0247/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0507/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0507/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0755/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0755/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0781/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0781/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0636/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0636/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0778/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0778/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0653/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0653/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0143/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0143/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0823/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0823/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0505/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0505/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0214/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0214/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0844/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0844/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0672/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0672/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0084/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0084/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0262/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0262/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0487/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0487/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0527/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0527/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0682/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0682/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1059/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1059/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0929/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0929/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0698/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0698/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0274/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0274/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0479/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0479/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1021/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1021/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0673/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0673/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0412/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0412/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0307/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0307/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0701/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0701/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0322/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0322/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1005/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1005/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0934/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0934/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1040/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1040/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1063/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1063/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0786/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0786/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0620/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0620/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0082/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0082/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0054/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0054/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1058/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1058/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0138/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0138/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0259/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0259/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0278/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0278/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0223/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0223/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0632/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0632/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0451/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0451/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0805/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0805/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1050/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1050/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0442/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0442/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0268/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0268/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0161/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0161/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0515/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0515/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0650/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0650/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0866/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0866/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0263/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0263/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0064/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0064/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0106/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0106/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0818/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0818/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0080/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0080/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0882/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0882/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0213/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0213/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0013/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0013/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0430/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0430/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0702/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0702/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0283/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0283/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0229/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0229/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0740/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0740/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0067/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0067/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0335/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0335/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0944/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0944/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0255/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0255/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0361/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0361/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0548/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0548/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1022/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1022/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0857/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0857/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0512/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0512/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0568/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0568/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0228/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0228/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0203/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0203/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0236/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0236/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0087/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0087/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0997/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0997/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0003/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0003/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0550/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0550/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0457/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0457/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0547/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0547/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0292/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0292/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0780/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0780/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0114/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0114/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0427/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0427/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0655/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0655/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0583/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0583/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0983/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0983/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0496/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0496/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0319/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0319/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0643/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0643/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0674/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0674/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0100/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0100/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0502/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0502/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0104/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0104/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0296/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0296/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0165/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0165/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0503/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0503/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0589/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0589/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0748/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0748/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0954/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0954/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0845/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0845/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0050/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0050/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0023/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0023/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0793/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0793/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0461/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0461/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1019/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1019/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0337/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0337/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0108/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0108/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0529/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0529/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0694/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0694/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0238/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0238/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0389/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0389/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0402/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0402/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0887/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0887/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0847/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0847/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0219/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0219/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0960/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0960/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0625/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0625/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0313/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0313/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0536/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0536/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0850/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0850/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0498/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0498/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0393/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0393/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0600/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0600/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0769/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0769/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1008/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1008/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0047/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0047/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0900/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0900/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0323/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0323/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1024/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1024/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0316/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0316/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0837/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0837/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0709/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0709/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0276/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0276/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0989/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0989/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0388/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0388/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0374/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0374/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0610/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0610/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0429/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0429/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0785/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0785/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1042/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1042/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0902/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0902/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0328/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0328/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0147/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0147/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0618/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0618/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1053/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1053/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0957/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0957/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0467/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0467/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0039/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0039/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0285/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0285/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0730/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0730/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0718/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0718/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0423/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0423/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0167/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0167/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0924/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0924/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0537/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0537/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0611/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0611/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0591/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0591/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0365/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0365/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0166/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0166/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0426/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0426/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0800/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0800/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0679/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0679/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0377/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0377/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0483/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0483/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0564/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0564/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0118/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0118/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0248/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0248/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0406/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0406/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0340/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0340/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0753/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0753/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0883/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0883/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0988/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0988/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0102/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0102/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0908/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0908/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0208/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0208/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0581/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0581/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0163/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0163/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0621/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0621/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0490/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0490/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0288/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0288/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0414/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0414/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0041/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0041/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0269/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0269/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1041/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1041/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0341/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0341/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0458/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0458/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0659/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0659/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0870/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0870/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0462/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0462/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0539/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0539/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0249/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0249/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0174/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0174/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0440/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0440/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0265/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0265/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0215/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0215/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0809/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0809/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0862/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0862/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0369/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0369/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0590/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0590/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0949/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0949/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0530/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0530/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0081/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0081/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0578/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0578/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0797/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0797/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0558/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0558/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0194/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0194/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0181/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0181/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0841/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0841/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0201/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0201/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0011/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0011/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0771/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0771/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0917/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0917/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0974/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0974/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0001/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0001/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0489/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0489/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0216/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0216/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0484/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0484/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0040/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0040/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0159/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0159/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0545/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0545/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0155/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0155/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0633/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0633/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0022/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0022/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0836/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0836/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0347/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0347/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0398/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0398/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0077/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0077/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0366/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0366/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1025/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_1025/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0097/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0097/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0176/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0176/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0310/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0310/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0044/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0044/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0052/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0052/file_1.txt
# ...
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0096/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0096/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0893/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0893/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0821/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0821/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0472/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0472/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0499/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/test/article_0499/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0026/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0026/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0075/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0075/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0063/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0063/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0094/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0094/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0071/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0071/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0073/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0073/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0090/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0090/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0085/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0085/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0084/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0084/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0082/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0082/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0054/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0054/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0064/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0064/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0080/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0080/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0013/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0013/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0067/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0067/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0087/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0087/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0003/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0003/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0050/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0050/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0023/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0023/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0047/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0047/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0039/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0039/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0041/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0041/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0081/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0081/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0011/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0011/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0001/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0001/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0040/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0040/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0022/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0022/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0077/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0077/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0044/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0044/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0052/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0052/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0056/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0056/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0000/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0000/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0046/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0046/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0009/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0009/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0010/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0010/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0008/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0008/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0042/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0042/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0043/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0043/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0006/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0006/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0093/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0093/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0072/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0072/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0019/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0019/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0007/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0007/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0076/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0076/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0004/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0004/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0049/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0049/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0062/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0062/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0061/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0061/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0057/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0057/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0027/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0027/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0035/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0035/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0045/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0045/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0086/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0086/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0014/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0014/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0065/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0065/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0068/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0068/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0074/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0074/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0030/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0030/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0032/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0032/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0060/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0060/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0005/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0005/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0091/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0091/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0015/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0015/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0017/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0017/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0048/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0048/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0069/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0069/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0024/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0024/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0078/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0078/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0025/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0025/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0092/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0092/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0031/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0031/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0034/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0034/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0051/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0051/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0028/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0028/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0036/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0036/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0059/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0059/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0088/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0088/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0029/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0029/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0058/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0058/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0079/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0079/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0038/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0038/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0033/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0033/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0037/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0037/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0018/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0018/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0012/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0012/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0002/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0002/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0066/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0066/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0020/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0020/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0083/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0083/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0055/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0055/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0021/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0021/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0070/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0070/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0053/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0053/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0016/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0016/file_1.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0089/file_2.txt
# /kaggle/input/fake-or-real-the-impostor-hunt/data/train/article_0089/file_1.txt

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

"""
SciBERT → Residual Stacking Ensemble for "Fake or Real: The Impostor Hunt"

- Stage 1: trains multiple base models (SVMs, Averaged SVM, Torch NN)
- Stage 2: meta-learners (LogReg, RF, HistGB, Torch NN) trained on residuals
- Stage 3: higher-level meta-learners trained on Stage 2 residuals
- Picks best Stage 2 learner via CV (Accuracy)
- Picks best Stage 3 learner via CV (R^2 on residual-target2 probabilities)

Supportive additions (cuML stacking tips):
- Optional GPU models (cuML) are added if available (no-op otherwise)
- Extra engineered meta features from Level-1 OOF predictions:
  consensus(mean), confidence(std), min, max, median, q25, q75, entropy
- NEW: Optional Level-3 weighted blend of top-2 Stage-2 meta learners (toggle)
"""

import os
import re
import random
from typing import List, Tuple, Optional

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from transformers import BertTokenizer, BertModel

from sklearn.model_selection import cross_val_predict
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, HistGradientBoostingClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, r2_score
from sklearn.base import BaseEstimator, ClassifierMixin

# ----------------------------- #
# Config
# ----------------------------- #

DATA_PREFIX = "/kaggle/input/fake-or-real-the-impostor-hunt/data/"
TRAIN_DIR = os.path.join(DATA_PREFIX, "train")
TEST_DIR = os.path.join(DATA_PREFIX, "test")
TRAIN_CSV = os.path.join(DATA_PREFIX, "train.csv")

MODEL_NAME = "allenai/scibert_scivocab_uncased"
BATCH_SIZE = 32
MAX_LEN = 512
DEVICE = "cpu"
SEED = 42

# Toggle: use Level-3 weighted blend of top-2 Stage-2 meta-learners
USE_WEIGHTED_L3 = True

EMB_CACHE_DIR = "./emb_cache"
os.makedirs(EMB_CACHE_DIR, exist_ok=True)
TRAIN_EMB_1_NPY = os.path.join(EMB_CACHE_DIR, "train_first_embeddings.npy")
TRAIN_EMB_2_NPY = os.path.join(EMB_CACHE_DIR, "train_second_embeddings.npy")
TEST_EMB_1_NPY = os.path.join(EMB_CACHE_DIR, "test_first_embeddings.npy")
TEST_EMB_2_NPY = os.path.join(EMB_CACHE_DIR, "test_second_embeddings.npy")

# ----------------------------- #
# Optional cuML (GPU) availability
# ----------------------------- #

def _try_import_cuml():
    try:
        import cuml
        from cuml.linear_model import LogisticRegression as cuLogReg
        from cuml.svm import SVC as cuSVC
        from cuml.ensemble import RandomForestClassifier as cuRF
        from cuml.neighbors import KNeighborsClassifier as cuKNN
        return {
            "ok": True,
            "cuLogReg": cuLogReg,
            "cuSVC": cuSVC,
            "cuRF": cuRF,
            "cuKNN": cuKNN
        }
    except Exception:
        return {"ok": False}

_CU = _try_import_cuml()

# ----------------------------- #
# Utilities
# ----------------------------- #

def set_seed(seed: int = 42) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

def safe_read_file(path: str) -> Optional[str]:
    try:
        with open(path, "r", encoding="utf-8") as f:
            return f.read().strip()
    except FileNotFoundError:
        return None
    except Exception:
        return None

def find_article_folders(parent: str) -> List[Tuple[int, str]]:
    out: List[Tuple[int, str]] = []
    for name in os.listdir(parent):
        m = re.match(r"article_(\d{4})$", name)
        if m:
            out.append((int(m.group(1)), name))
    out.sort(key=lambda x: x[0])
    return out

def load_pairs(data_folder: str) -> List[Tuple[int, str, str]]:
    pairs: List[Tuple[int, str, str]] = []
    folders = find_article_folders(data_folder)
    for art_id, folder in folders:
        f1 = safe_read_file(os.path.join(data_folder, folder, "file_1.txt"))
        f2 = safe_read_file(os.path.join(data_folder, folder, "file_2.txt"))
        if f1 is None or f2 is None:
            raise RuntimeError(f"Missing files for {folder}")
        pairs.append((art_id, f1, f2))
    return pairs

def load_labels(labels_csv: str) -> pd.DataFrame:
    return pd.read_csv(labels_csv)

# ----------------------------- #
# BERT Embeddings
# ----------------------------- #

class BertEmbedder:
    def __init__(self, model_name: str, device: str = "cpu", max_len: int = 512):
        self.device = torch.device(device)
        self.max_len = max_len
        self.tokenizer = BertTokenizer.from_pretrained(model_name)
        self.model = BertModel.from_pretrained(model_name).to(self.device)
        self.model.eval()

    @torch.no_grad()
    def encode(self, texts: List[str], batch_size: int = 32) -> np.ndarray:
        all_batches = []
        for i in range(0, len(texts), batch_size):
            batch = texts[i: i + batch_size]
            inputs = self.tokenizer(
                batch, return_tensors="pt", truncation=True, padding=True, max_length=self.max_len
            ).to(self.device)
            outputs = self.model(**inputs)
            token_emb = outputs.last_hidden_state
            mask = inputs["attention_mask"].unsqueeze(-1)
            masked_sum = (token_emb * mask).sum(dim=1)
            lengths = mask.sum(dim=1).clamp(min=1)
            mean_emb = masked_sum / lengths
            all_batches.append(mean_emb.detach().cpu().numpy())
        return np.concatenate(all_batches, axis=0)

# ----------------------------- #
# Dataset helpers
# ----------------------------- #

def build_all_embeddings(first_emb, second_emb, labels_df):
    X_list, y_list = [], []
    for i in range(len(labels_df)):
        real_id = labels_df.iloc[i].real_text_id
        X_list.append(first_emb[i]); y_list.append(1 if real_id == 1 else 0)
        X_list.append(second_emb[i]); y_list.append(1 if real_id == 2 else 0)
    return np.stack(X_list, axis=0), np.array(y_list, dtype=int)

# ----------------------------- #
# Kernels
# ----------------------------- #

def _rbf_kernel(X, Y, gamma=None):
    if gamma is None:
        gamma = 1.0 / max(1, X.shape[1])
    X_norm = (X * X).sum(axis=1)[:, None]
    Y_norm = (Y * Y).sum(axis=1)[None, :]
    K = X_norm + Y_norm - 2.0 * (X @ Y.T)
    return np.exp(-gamma * K)

def _sigmoid_kernel(X, Y, gamma=None, coef0=0.0):
    if gamma is None:
        gamma = 1.0 / max(1, X.shape[1])
    return np.tanh(gamma * (X @ Y.T) + coef0)

def kernel_rbf_plus_sigmoid_avg(X, Y):
    return 0.5 * (_rbf_kernel(X, Y) + _sigmoid_kernel(X, Y))

def kernel_rbf_plus_sigmoid_sum(X, Y):
    return _rbf_kernel(X, Y) + _sigmoid_kernel(X, Y)

# ----------------------------- #
# Torch NN
# ----------------------------- #

class TorchNN(BaseEstimator, ClassifierMixin):
    def __init__(self, hidden_dim=64, epochs=5, batch_size=128, lr=1e-3, random_state=SEED):
        self.hidden_dim = hidden_dim
        self.epochs = epochs
        self.batch_size = batch_size
        self.lr = lr
        self.random_state = random_state
        self._model = None
        self.classes_ = np.array([0, 1], dtype=int)

    class _Net(nn.Module):
        def __init__(self, in_dim, hidden):
            super().__init__()
            self.seq = nn.Sequential(
                nn.Linear(in_dim, hidden),
                nn.ReLU(),
                nn.Linear(hidden, 1)
            )
        def forward(self, x):
            return self.seq(x).squeeze(-1)

    def fit(self, X, y):
        torch.manual_seed(self.random_state)
        self._model = self._Net(X.shape[1], self.hidden_dim)
        ds = TensorDataset(
            torch.tensor(X, dtype=torch.float32),
            torch.tensor(y, dtype=torch.float32)
        )
        dl = DataLoader(ds, batch_size=self.batch_size, shuffle=True)
        opt = torch.optim.Adam(self._model.parameters(), lr=self.lr)
        crit = nn.BCEWithLogitsLoss()
        self._model.train()
        for _ in range(self.epochs):
            for xb, yb in dl:
                opt.zero_grad()
                logit = self._model(xb)
                loss = crit(logit, yb)
                loss.backward()
                opt.step()
        return self

    def predict_proba(self, X):
        self._model.eval()
        xb = torch.tensor(X, dtype=torch.float32)
        with torch.no_grad():
            logit = self._model(xb)
            p1 = torch.sigmoid(logit).numpy()
        return np.stack([1 - p1, p1], axis=1)

    def decision_function(self, X):
        return self.predict_proba(X)[:, 1]

    def predict(self, X):
        return (self.decision_function(X) >= 0.5).astype(int)

# ----------------------------- #
# Meta features from Level-1 predictions
# ----------------------------- #

def _entropy(p, eps=1e-12):
    p = np.clip(p, eps, 1 - eps)
    return -(p * np.log(p) + (1 - p) * np.log(1 - p))

def build_meta_features(pred_matrix: np.ndarray) -> np.ndarray:
    mean = pred_matrix.mean(axis=1, keepdims=True)
    std = pred_matrix.std(axis=1, keepdims=True)
    mn = pred_matrix.min(axis=1, keepdims=True)
    mx = pred_matrix.max(axis=1, keepdims=True)
    med = np.median(pred_matrix, axis=1, keepdims=True)
    q25 = np.quantile(pred_matrix, 0.25, axis=1, keepdims=True)
    q75 = np.quantile(pred_matrix, 0.75, axis=1, keepdims=True)
    ent = _entropy(mean.squeeze(1)).reshape(-1, 1)
    return np.concatenate([pred_matrix, mean, std, mn, mx, med, q25, q75, ent], axis=1)

# ----------------------------- #
# Residual Stacking Classifier
# ----------------------------- #

class ResidualStackingClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, random_state=SEED):
        self.random_state = random_state
        # Base models
        self.base_models = {
            "SVM-RBF": Pipeline([("scaler", StandardScaler()), ("clf", SVC(kernel="rbf", probability=True))]),
            "SVM-Sigmoid": Pipeline([("scaler", StandardScaler()), ("clf", SVC(kernel="sigmoid", probability=True))]),
            "Torch-NN": Pipeline([("scaler", StandardScaler()), ("clf", TorchNN(hidden_dim=64, epochs=3))]),
        }
        # Meta learners Stage 2
        self.meta_learners_stage2 = {
            "LogReg": LogisticRegression(max_iter=2000),
            "RF": RandomForestClassifier(n_estimators=200, random_state=SEED),
            "HistGB": HistGradientBoostingClassifier(random_state=SEED),
        }
        # Meta learners Stage 3
        self.meta_learners_stage3 = {
            "LogReg": LogisticRegression(max_iter=2000),
            "GB": GradientBoostingClassifier(random_state=SEED),
            "RF": RandomForestClassifier(n_estimators=300, random_state=SEED),
        }
        self.best_meta2 = None
        self.best_meta3 = None
        self.stage2_ranked = []
        self.fitted_models = {}

    def fit(self, X, y):
        # Stage 1
        oof_preds = np.zeros((X.shape[0], len(self.base_models)))
        for j, (name, pipe) in enumerate(self.base_models.items()):
            preds = cross_val_predict(pipe, X, y, cv=5, method="predict_proba")[:, 1]
            oof_preds[:, j] = preds
            self.fitted_models[name] = pipe.fit(X, y)
        oof_meta = build_meta_features(oof_preds)
        stage1_pred = (oof_preds.mean(axis=1) >= 0.5).astype(int)
        residual_target = (y != stage1_pred).astype(int)
        # Stage 2
        best_score2 = -1
        for name, meta in self.meta_learners_stage2.items():
            preds_meta = cross_val_predict(meta, oof_meta, residual_target, cv=5, method="predict")
            score = accuracy_score(residual_target, preds_meta)
            fit_model = meta.fit(oof_meta, residual_target)
            self.stage2_ranked.append((name, fit_model, score))
            if score > best_score2:
                best_score2 = score
                self.best_meta2 = (name, fit_model)
        self.stage2_ranked.sort(key=lambda t: t[2], reverse=True)
        print(f"[Stage2] Selected meta-learner: {self.best_meta2[0]} | Acc={best_score2:.4f}")
        # Stage 3
        stage2_residual_pred = self.best_meta2[1].predict(oof_meta)
        residual_target2 = (residual_target != stage2_residual_pred).astype(int)
        best_r2 = -1e9
        for name, meta in self.meta_learners_stage3.items():
            prob_pred = cross_val_predict(meta, oof_meta, residual_target2, cv=5, method="predict_proba")[:, 1]
            score_r2 = r2_score(residual_target2.astype(float), prob_pred.astype(float))
            if score_r2 > best_r2:
                best_r2 = score_r2
                self.best_meta3 = (name, meta.fit(oof_meta, residual_target2))
        print(f"[Stage3] Selected meta-learner by R^2: {self.best_meta3[0]} | R^2={best_r2:.4f}")
        return self

    def _base_pred_matrix(self, X) -> np.ndarray:
        cols = []
        for name, model in self.fitted_models.items():
            p = model.predict_proba(X)[:, 1]
            cols.append(p)
        return np.vstack(cols).T

    def predict(self, X):
        base_preds = self._base_pred_matrix(X)
        avg_base = base_preds.mean(axis=1)
        base_meta = build_meta_features(base_preds)
        residual_prob2 = self.best_meta2[1].predict_proba(base_meta)[:, 1]
        baseline = (avg_base >= 0.5).astype(int)
        stage2_fix = np.where(residual_prob2 > 0.5, 1 - baseline, baseline)
        residual_prob3 = self.best_meta3[1].predict_proba(base_meta)[:, 1]
        return np.where(residual_prob3 > 0.5, 1 - stage2_fix, stage2_fix)

    def decision_function(self, X):
        base_preds = self._base_pred_matrix(X)
        return base_preds.mean(axis=1)

# ----------------------------- #
# Main
# ----------------------------- #

def main():
    set_seed(SEED)
    train_labels = load_labels(TRAIN_CSV)
    train_pairs = load_pairs(TRAIN_DIR)
    test_pairs = load_pairs(TEST_DIR)

    id_to_train = {aid: (t1, t2) for (aid, t1, t2) in train_pairs}
    first_train_texts = [id_to_train[i][0] for i in train_labels["id"].values]
    second_train_texts = [id_to_train[i][1] for i in train_labels["id"].values]
    test_ids = [aid for (aid, _, _) in test_pairs]
    first_test_texts = [t1 for (_, t1, _) in test_pairs]
    second_test_texts = [t2 for (_, _, t2) in test_pairs]

    embedder = BertEmbedder(MODEL_NAME, device=DEVICE, max_len=MAX_LEN)

    def maybe_encode(texts, cache_path):
        if os.path.exists(cache_path):
            arr = np.load(cache_path)
            if arr.ndim == 2:
                return arr
        arr = embedder.encode(texts, batch_size=BATCH_SIZE)
        np.save(cache_path, arr)
        return arr

    first_train_emb = maybe_encode(first_train_texts, TRAIN_EMB_1_NPY)
    second_train_emb = maybe_encode(second_train_texts, TRAIN_EMB_2_NPY)
    first_test_emb = maybe_encode(first_test_texts, TEST_EMB_1_NPY)
    second_test_emb = maybe_encode(second_test_texts, TEST_EMB_2_NPY)

    X, y = build_all_embeddings(first_train_emb, second_train_emb, train_labels)

    clf = ResidualStackingClassifier().fit(X, y)
    s1, s2 = clf.decision_function(first_test_emb), clf.decision_function(second_test_emb)
    preds = np.where(s1 > s2, 1, 2)

    pd.DataFrame({"id": test_ids, "real_text_id": preds}).to_csv("submission.csv", index=False)
    print("[OK] Saved submission.csv")

if __name__ == "__main__":
    main()
# Out:
# 2025-09-23 02:30:36.665507: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758594636.928670      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758594637.004520      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/local/lib/python3.11/dist-packages/cudf/utils/_ptxcompiler.py:64: UserWarning: Error getting driver and runtime versions:
#
# stdout:
#
#
#
# stderr:
#
# Traceback (most recent call last):
#   File "<string>", line 4, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/numba_cuda/numba/cuda/cudadrv/driver.py", line 314, in __getattr__
#     raise CudaSupportError("Error at driver init: \n%s:" %
# numba.cuda.cudadrv.error.CudaSupportError: Error at driver init:
#
# CUDA driver library cannot be found.
# If you are sure that a CUDA driver is installed,
# try setting environment variable NUMBA_CUDA_DRIVER
# with the file path of the CUDA driver shared library.
# :
#
#
# Not patching Numba
#   warnings.warn(msg, UserWarning)
# vocab.txt: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/442M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/442M [00:00<?, ?B/s]
# [Stage2] Selected meta-learner: LogReg | Acc=0.8053
# [Stage3] Selected meta-learner by R^2: LogReg | R^2=0.0346
# [OK] Saved submission.csv
